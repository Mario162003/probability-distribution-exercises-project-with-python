# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment; for example, when you flip a coin, it can be either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
qbinom(0.5, 10, 0.5)
# Out:
# np.float64(5.0)

# %%
# Binomial(10, 0.2) distribution, where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999997
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros de la distribución binomial
n = 10
p = 0.2
size = 2000

# Generar valores aleatorios
data = np.random.binomial(n, p, size)

# Gráfico del histograma
plt.hist(data, bins=np.arange(-0.5, n + 1, 1), density=True, edgecolor='black', alpha=0.7)
plt.title('Distribución Binomial (n=10, p=0.2)')
plt.xlabel('Número de Éxitos')
plt.ylabel('Frecuencia Relativa')
plt.xticks(range(n + 1))
plt.grid(True)
plt.show()

dbinom(5,10,0.2)
# Out:
# np.float64(0.026424115199999987)

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)
q = np.linspace(0,0.99,2000)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 10))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()
# Show the plot
plt.show()
data
# Out:
# array([1, 4, 3, ..., 0, 0, 1])

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %%
# TODO
import scipy.stats as stats
from scipy.stats import norm

#Normal Distribution
def dnorm(x, mean = 0, std = 1):
    """
    Calculates the density of the normal distribution
    """
    result = norm.pdf(x, loc = mean, scale = std)

    return result

def pnorm(x, mean = 0, std = 1):
    """
    Calculates the cumulative of the normal distribution
    """
    result = norm.cdf(x = x, loc = mean, scale = std)

    return result

def qnorm(p, mean = 0, std = 1):
    """
    Calculates the quantile function from the normal distribution
    """
    result = norm.ppf(q = p, loc = mean, scale = std)

    return result

def rnorm(n, mean = 0, std = 1):
    """
    Generates random variables from the normal distribution
    """
    result = norm.rvs(size = n, loc = mean, scale = std)

    return result

# %%
qnorm(0.05,10,2)
# Out:
# np.float64(6.710292746097054)

# %%
import matplotlib.pyplot as plt

np.random.seed(12)
data = rnorm(2000, mean= 10, std = 0.5)
x = np.linspace(qnorm(0.01,10,0.5),qnorm(0.99,10,0.5),2000)
y = np.linspace(0.01,0.99,2000)
#plt.hist(data, bins= 20)
#plt.axvline(10, color = 'g')

pdf = dnorm(data,10,0.5)
cdf = pnorm(data,10,0.5)
#ppf = qnorm(data,10,0.5)

fig, axis = plt.subplots(3, 1, figsize = (5, 10))

axis[0].stem(data, pdf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(y, x, "g-") 

plt.tight_layout()
plt.show()

# %%
# uniform
import numpy as np
from scipy.stats import uniform

def duni(x, low = 0, high = 1):
    result = uniform.pdf(x, loc = low, scale = (high - low))
    return result

def puni(q, low = 0, high = 1):
    result = uniform.cdf(q, loc = low, scale = (high - low))
    return result

def quni(p, low = 0, high = 1):
    result = uniform.ppf(p, loc = low, scale = (high - low))
    return result

def runi(n, low = 0, high = 1):
    result = uniform.rvs(loc = low, scale = (high - low), size = n)
    return result

# %%
np.random.seed(42)
low = 0
high = 5
data = np.arange(-5, 10, 0.01)

pmf = duni(data, low = low, high = high)
cdf = puni(data, low = low, high = high)
ppf = quni(data, low = low, high = high)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].plot(data, pmf, "r-")
axis[1].plot(data, cdf, "b-")
axis[2].plot(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
